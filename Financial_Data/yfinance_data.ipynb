# %%
import os
from os import path
from os import environ
import pandas as pd
import numpy as np
from sqlalchemy import create_engine
import logging
from dateutil.rrule import rrule, DAILY
import yfinance as yf
from dotenv import load_dotenv
from datetime import datetime, timedelta
import pytz
import time
import argparse
import dataUtil as DU
# Out:
# C:\Users\Asus\anaconda3\envs\QuantAnalysis\lib\site-packages\paramiko\transport.py:219: CryptographyDeprecationWarning: Blowfish has been deprecated and will be removed in a future release
#   "class": algorithms.Blowfish,

# %%
load_dotenv()
DB = environ.get("DBMKTDATA")
print(DB)
# Out:
# GlobalMarketData

# %%
engine = DU.get_DBengine()
engine
# Out:
# Engine(mysql+pymysql://thomas:***@db-mysql-sfo3-81086-do-user-14080938-0.b.db.ondigitalocean.com:25060/GlobalMarketData)

# %%
sql= "call GlobalMarketData.current_symbols_V2;"

# %%
# symbol_list = DU.load_symbols("master_db_list")

# %%
symbol_list = pd.read_sql(sql, engine)
print(symbol_list)
# Out:
#     Symbol
# 0      AAL
# 1     AAPL
# 2     ABNB
# 3     AMAT
# 4      AMC
# ..     ...
# 197    XOP
# 198     YI
# 199     YJ
# 200     YY
# 201     ZI
#
# [202 rows x 1 columns]

# %%
sym_list = symbol_list['Symbol'].to_list()
print(sym_list)
# Out:
# ['AAL', 'AAPL', 'ABNB', 'AMAT', 'AMC', 'AMD', 'AMLP', 'ATAI', 'ATVI', 'AVTR', 'BA', 'BAC', 'BBY', 'BEN', 'BGNE', 'BIDU', 'BILI', 'BKR', 'BMY', 'BRO', 'BSX', 'BTC-USD', 'BX', 'C', 'CAAS', 'CBAT', 'CCL', 'CHK', 'CHNR', 'CJJD', 'CLF', 'CMCSA', 'CNET', 'COIN', 'COP', 'CREG', 'CSCO', 'CSIQ', 'CSX', 'CTLT', 'CTRA', 'CVS', 'CVX', 'CZR', 'DAL', 'DASH', 'DBA', 'DIS', 'DKNG', 'DVN', 'EBAY', 'EFA', 'EFV', 'EMB', 'ENPH', 'EPD', 'ETH-USD', 'EWA', 'EWU', 'EWW', 'EWZ', 'F', 'FCX', 'FE', 'FL', 'FNF', 'GIGM', 'GILD', 'GLD', 'GLW', 'GM', 'GURE', 'HIMX', 'HOLI', 'HPQ', 'HTHT', 'HYG', 'IBM', 'INDA', 'INTC', 'IP', 'IPG', 'IQ', 'IWM', 'IYR', 'JD', 'JG', 'JNJ', 'JNK', 'JPM', 'KDP', 'KHC', 'KNDI', 'KO', 'KSS', 'KVUE', 'LQD', 'LX', 'LYB', 'LYV', 'M', 'MDLZ', 'MMM', 'MO', 'MRK', 'MRNA', 'MRO', 'MRVL', 'MS', 'MSFT', 'MTC', 'MTCH', 'MU', 'NCTY', 'NEM', 'NFLX', 'NIU', 'NKLA', 'NTES', 'NVDA', 'NVFY', 'O', 'OKE', 'ON', 'ORCL', 'OXY', 'PANW', 'PARA', 'PDD', 'PEAK', 'PFE', 'PFF', 'PG', 'PINS', 'PLTR', 'PLUG', 'PM', 
# ...

# %%
edate = datetime.now().date()
sdate = edate - timedelta(days=10)

# %%
sDF = yf.download(sym_list,sdate,edate)
# Out:
# [*************         27%%                      ]  54 of 202 completedWARNING:urllib3.connectionpool:Connection pool is full, discarding connection: query2.finance.yahoo.com. Connection pool size: 10
# [*************         27%%                      ]  55 of 202 completedWARNING:urllib3.connectionpool:Connection pool is full, discarding connection: query2.finance.yahoo.com. Connection pool size: 10
# [**************        29%%                      ]  58 of 202 completedWARNING:urllib3.connectionpool:Connection pool is full, discarding connection: query2.finance.yahoo.com. Connection pool size: 10
# WARNING:urllib3.connectionpool:Connection pool is full, discarding connection: query2.finance.yahoo.com. Connection pool size: 10
# [**************        29%%                      ]  59 of 202 completedWARNING:urllib3.connectionpool:Connection pool is full, discarding connection: query2.finance.yahoo.com. Connection pool size: 10
# ...

# %%
c_cols=['Close','Open','High','Low','Volume','Adj Close']

# %%
sDF_1 = sDF.reset_index()
sDF_1.head()
# Out:
# Price        Date Adj Close                                            \
# Ticker                  AAL        AAPL        ABNB        AMAT   AMC
# 0      2024-03-24       NaN         NaN         NaN         NaN   NaN
# 1      2024-03-25     14.92  170.850006  167.990005  208.460007  4.09
# 2      2024-03-26     14.92  169.710007  167.389999  206.669998  4.07
# 3      2024-03-27     15.30  173.309998  166.410004  208.000000  4.34
# 4      2024-03-28     15.35  171.479996  164.960007  206.229996  3.72
#
# Price                                     ...     Volume              \
# Ticker         AMD       AMLP  ATAI ATVI  ...        XHB         XLE
# 0              NaN        NaN   NaN  NaN  ...        NaN         NaN
# 1       178.630005  46.959999  1.66  NaN  ...  1518400.0  17537200.0
# 2       177.869995  46.849998  1.73  NaN  ...  1105600.0  17686900.0
# 3       179.589996  47.090000  1.79  NaN  ...  1854100.0  16980000.0
# ...

# %%
sDF_1 = sDF['Adj Close'].reset_index()
sDF_1.head()
# Out:
# Ticker       Date    AAL        AAPL        ABNB        AMAT   AMC  \
# 0      2024-03-24    NaN         NaN         NaN         NaN   NaN
# 1      2024-03-25  14.92  170.850006  167.990005  208.460007  4.09
# 2      2024-03-26  14.92  169.710007  167.389999  206.669998  4.07
# 3      2024-03-27  15.30  173.309998  166.410004  208.000000  4.34
# 4      2024-03-28  15.35  171.479996  164.960007  206.229996  3.72
#
# Ticker         AMD       AMLP  ATAI  ATVI  ...         XHB        XLE  \
# 0              NaN        NaN   NaN   NaN  ...         NaN        NaN
# 1       178.630005  46.959999  1.66   NaN  ...  109.540001  93.260002
# 2       177.869995  46.849998  1.73   NaN  ...  109.330002  92.540001
# 3       179.589996  47.090000  1.79   NaN  ...  110.650002  93.400002
# 4       180.490005  47.459999  1.97   NaN  ...  111.589996  94.410004
#
# Ticker        XME   XNET         XOM         XOP    YI     YJ     YY  \
# ...

# %%
sDF_1.melt(id_vars=['Date'], var_name='Symbol', value_name='AdjClose')
# Out:
#            Date Symbol  AdjClose
# 0    2024-03-24    AAL       NaN
# 1    2024-03-25    AAL     14.92
# 2    2024-03-26    AAL     14.92
# 3    2024-03-27    AAL     15.30
# 4    2024-03-28    AAL     15.35
# ...         ...    ...       ...
# 6055 2024-04-18     ZI     15.77
# 6056 2024-04-19     ZI     15.53
# 6057 2024-04-20     ZI       NaN
# 6058 2024-04-21     ZI       NaN
# 6059 2024-04-22     ZI     15.66
#
# [6060 rows x 3 columns]
